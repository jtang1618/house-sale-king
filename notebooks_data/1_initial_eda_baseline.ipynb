# %% [markdown]
# # King County House Sales dataset

# %% [markdown]
# ## Initial Setup

# %% [markdown]
# **Libraries used:** NumPy, Pandas, Pandas-Profiling, SciPy, Seaborn, MatPlotLib, Folium, Cufflinks, Datetime, Sweetviz

# %%
#Setting up environment with initial libraries needed for importing, cleaning, and initial visualization
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport
from scipy import stats

import seaborn as sns
import matplotlib.pyplot as plt
import folium
from folium.plugins import HeatMap
import sweetviz as sv

import cufflinks as cf
from datetime import datetime

import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
from statsmodels.formula.api import ols

import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_rows', 30)
pd.set_option('display.max_columns', 25)
pd.set_option('display.float_format', '{:,}'.format)

sns.set_style('darkgrid')

# %matplotlib inline
# Out:
# C:\Users\jtang\anaconda3\envs\learn-env\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Importing the House Sales data

# %% [markdown]
# The dataset contains sales data of houses sold in King County, WA from May 2014 to May 2015, consisting of 21,597 rows and 21 columns. A list of all column names and their descriptions are outlined in the [kchouse_columns](kchouse_columns.ipynb) notebook.

# %%
# Importing the King County House Sales csv into a dataframe with Pandas and assigning it to the variable kchouse_df
kchouse_df = pd.read_csv('kc_house_data.csv')

# Verifying dataset has been imported correctly as a dataframe using the first five rows of data
kchouse_df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014 221,900.0         3        1.0         1180
# 1  6414100192   12/9/2014 538,000.0         3       2.25         2570
# 2  5631500400   2/25/2015 180,000.0         2        1.0          770
# 3  2487200875   12/9/2014 604,000.0         4        3.0         1960
# 4  1954400510   2/18/2015 510,000.0         3        2.0         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0         nan   0.0          3      7        1180
# 1      7242     2.0         0.0   0.0          3      7        2170
# 2     10000     1.0         0.0   0.0          3      6         770
# 3      5000     1.0         0.0   0.0          5      7        1050
# 4      8080     1.0         0.0   0.0          3      8        1680
#
#   sqft_basement  yr_built  yr_renovated  zipcode                lat  \
# 0           0.0      1955           0.0    98178            47.5112
# 1         400.0      1951       1,991.0    98125 47.721000000000004
# 2           0.0      1933           nan    98028            47.7379
# 3         910.0      1965           0.0    98136            47.5208
# 4           0.0      1987           0.0    98074            47.6168
#
#                  long  sqft_living15  sqft_lot15
# 0            -122.257           1340        5650
# 1            -122.319           1690        7639
# 2 -122.23299999999999           2720        8062
# 3 -122.39299999999999           1360        5000
# 4            -122.045           1800        7503

# %%
#calling overall shape of the dataframe
kchouse_df.shape
# Out:
# (21597, 21)

# %%
kchouse_df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning & EDA

# %% [markdown]
# ### Initial cleaning and EDA

# %%
#print summary of dataframe
kchouse_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %%
#return unique count of datatypes
kchouse_df.dtypes.value_counts()
# Out:
# int64      11
# float64     8
# object      2
# dtype: int64

# %%
#return all object datatype columns
kchouse_df.select_dtypes(include='object').columns
# Out:
# Index(['date', 'sqft_basement'], dtype='object')

# %%
#checking for the sum of missing values and percentages within each column
for col in kchouse_df:
    mv = kchouse_df[col].isna().sum()
    if mv > 0:
        print(f'{col} column has {mv} missing values')
# Out:
# waterfront column has 2376 missing values
# view column has 63 missing values
# yr_renovated column has 3842 missing values

# %%
#checking for duplicate rows across all columns
duplicate_rows = kchouse_df[kchouse_df.duplicated()]
print(f"The are {len(duplicate_rows)} duplicate rows in the dataframe.")
# Out:
# The are 0 duplicate rows in the dataframe.

# %%
#checking for duplicate values within each column
for col in kchouse_df:
    dupe = kchouse_df[col].duplicated().sum()
    dupe_per = round(kchouse_df[col].duplicated().sum()/len(kchouse_df) * 100, 3)
    print(f'{col} | {dupe} | {dupe_per}%')
# Out:
# id | 177 | 0.82%
# date | 21225 | 98.278%
# price | 17975 | 83.229%
# bedrooms | 21585 | 99.944%
# bathrooms | 21568 | 99.866%
# sqft_living | 20563 | 95.212%
# sqft_lot | 11821 | 54.734%
# floors | 21591 | 99.972%
# waterfront | 21594 | 99.986%
# view | 21591 | 99.972%
# condition | 21592 | 99.977%
# grade | 21586 | 99.949%
# sqft_above | 20655 | 95.638%
# sqft_basement | 21293 | 98.592%
# yr_built | 21481 | 99.463%
# yr_renovated | 21526 | 99.671%
# zipcode | 21527 | 99.676%
# lat | 16564 | 76.696%
# long | 20846 | 96.523%
# sqft_living15 | 20820 | 96.402%
# sqft_lot15 | 12915 | 59.8%

# %%
#call descriptive statistics of dataframe
kchouse_df.describe()
# Out:
#                         id              price           bedrooms  \
# count             21,597.0           21,597.0           21,597.0
# mean  4,580,474,287.770987 540,296.5735055795 3.3731999814789093
# std    2,876,735,715.74778 367,368.1401013945 0.9262988945421479
# min            1,000,102.0           78,000.0                1.0
# 25%        2,123,049,175.0          322,000.0                3.0
# 50%        3,904,930,410.0          450,000.0                3.0
# 75%        7,308,900,490.0          645,000.0                4.0
# max        9,900,000,190.0        7,700,000.0               33.0
#
#                bathrooms         sqft_living            sqft_lot  \
# count           21,597.0            21,597.0            21,597.0
# mean  2.1158262721674306 2,080.3218502569803 15,099.408760475992
# std   0.7689842966527209   918.1061250800805 41,412.636875502074
# min                  0.5               370.0               520.0
# 25%                 1.75             1,430.0             5,040.0
# 50%                 2.25             1,910.0             7,618.0
# 75%                  2.5             2,550.0            10,685.0
# max                  8.0            13,540.0         1,651,359.0
#
#                   floors           waterfront                view  \
# count           21,597.0             19,221.0            21,534.0
# mean  1.4940964022780943 0.007595858696217679 0.23386272870808952
# std   0.5396827909775457  0.08682484570054606  0.7656862011746727
# min                  1.0                  0.0                 0.0
# 25%                  1.0                  0.0                 0.0
# 50%                  1.5                  0.0                 0.0
# 75%                  2.0                  0.0                 0.0
# max                  3.5                  1.0                 4.0
#
#                condition              grade          sqft_above  \
# count           21,597.0           21,597.0            21,597.0
# mean  3.4098254387183404  7.657915451220076 1,788.5968421540028
# std   0.6505456356725546 1.1731996637760254   827.7597611646754
# min                  1.0                3.0               370.0
# 25%                  3.0                7.0             1,190.0
# 50%                  3.0                7.0             1,560.0
# 75%                  4.0                8.0             2,210.0
# max                  5.0               13.0             9,410.0
#
#                  yr_built      yr_renovated            zipcode  \
# count            21,597.0          17,755.0           21,597.0
# mean  1,970.9996758809093  83.6367783722895 98,077.95184516368
# std    29.375234132441644 399.9464138788162  53.51307235352816
# min               1,900.0               0.0           98,001.0
# 25%               1,951.0               0.0           98,033.0
# 50%               1,975.0               0.0           98,065.0
# 75%               1,997.0               0.0           98,118.0
# max               2,015.0           2,015.0           98,199.0
#
#                       lat                long       sqft_living15  \
# count            21,597.0            21,597.0            21,597.0
# mean    47.56009299439737  -122.2139824975691 1,986.6203176367087
# std   0.13855176817307177 0.14072352882947373   685.2304719001586
# min               47.1559 -122.51899999999999               399.0
# 25%               47.4711 -122.32799999999999             1,490.0
# 50%               47.5718 -122.23100000000001             1,840.0
# 75%    47.678000000000004            -122.125             2,360.0
# max               47.7776            -121.315             6,210.0
#
#                sqft_lot15
# count            21,597.0
# mean  12,758.283511598833
# std   27,274.441950386343
# min                 651.0
# 25%               5,100.0
# 50%               7,620.0
# 75%              10,083.0
# max             871,200.0

# %%
#define function to iterate through columns for custom descriptive statistics table
def eda_table(df): 
    eda_df = {}
    eda_df['null_sum'] = df.isna().sum()
    eda_df['null_prct'] = df.isna().mean()
    eda_df['dtypes'] = df.dtypes
    eda_df['count'] = df.count()
    eda_df['mean'] = df.mean()
    eda_df['median'] = df.median()
    eda_df['min'] = df.min()
    eda_df['max'] = df.max()
    
    return pd.DataFrame(eda_df)

# %%
#call function on dataframe
eda_table(kchouse_df)
# Out:
#                null_sum             null_prct   dtypes  count  \
# bathrooms             0                   0.0  float64  21597
# bedrooms              0                   0.0    int64  21597
# condition             0                   0.0    int64  21597
# date                  0                   0.0   object  21597
# floors                0                   0.0  float64  21597
# grade                 0                   0.0    int64  21597
# id                    0                   0.0    int64  21597
# lat                   0                   0.0  float64  21597
# long                  0                   0.0  float64  21597
# price                 0                   0.0  float64  21597
# sqft_above            0                   0.0    int64  21597
# sqft_basement         0                   0.0   object  21597
# sqft_living           0                   0.0    int64  21597
# sqft_living15         0                   0.0    int64  21597
# sqft_lot              0                   0.0    int64  21597
# sqft_lot15            0                   0.0    int64  21597
# view                 63 0.0029170718155299346  float64  21534
# waterfront         2376   0.11001527989998611  float64  19221
# yr_built              0                   0.0    int64  21597
# yr_renovated       3842   0.17789507802009538  float64  17755
# zipcode               0                   0.0    int64  21597
#
#                               mean              median                 min  \
# bathrooms       2.1158262721674306                2.25                 0.5
# bedrooms        3.3731999814789093                 3.0                   1
# condition       3.4098254387183404                 3.0                   1
# date                           nan                 nan           1/10/2015
# floors          1.4940964022780943                 1.5                 1.0
# grade            7.657915451220076                 7.0                   3
# id            4,580,474,287.770987     3,904,930,410.0             1000102
# lat              47.56009299439737             47.5718             47.1559
# long            -122.2139824975691 -122.23100000000001 -122.51899999999999
# price           540,296.5735055795           450,000.0            78,000.0
# sqft_above     1,788.5968421540028             1,560.0                 370
# sqft_basement                  nan                 nan                 0.0
# sqft_living    2,080.3218502569803             1,910.0                 370
# sqft_living15  1,986.6203176367087             1,840.0                 399
# sqft_lot       15,099.408760475992             7,618.0                 520
# sqft_lot15     12,758.283511598833             7,620.0                 651
# view           0.23386272870808952                 0.0                 0.0
# waterfront    0.007595858696217679                 0.0                 0.0
# yr_built       1,970.9996758809093             1,975.0                1900
# yr_renovated      83.6367783722895                 0.0                 0.0
# zipcode         98,077.95184516368            98,065.0               98001
#
#                       max
# bathrooms             8.0
# bedrooms               33
# condition               5
# date             9/9/2014
# floors                3.5
# grade                  13
# id             9900000190
# lat               47.7776
# long             -121.315
# price         7,700,000.0
# sqft_above           9410
# sqft_basement           ?
# sqft_living         13540
# sqft_living15        6210
# sqft_lot          1651359
# sqft_lot15         871200
# view                  4.0
# waterfront            1.0
# yr_built             2015
# yr_renovated      2,015.0
# zipcode             98199

# %%
#check the number unique values as a percentage of total column values
for col in kchouse_df.columns:
    print(col)
    print(kchouse_df[col].value_counts(normalize=True) * 100)
    print('\n')
# Out:
# id
# 795000620    0.013890818169190166
# 1825069031   0.009260545446126776
# 2019200220   0.009260545446126776
# 7129304540   0.009260545446126776
# 1781500435   0.009260545446126776
#                      ...
# 7812801125   0.004630272723063388
# 4364700875   0.004630272723063388
# 3021059276   0.004630272723063388
# 880000205    0.004630272723063388
# 1777500160   0.004630272723063388
# Name: id, Length: 21420, dtype: float64
#
#
# date
# 6/23/2014     0.6574987266750012
# 6/26/2014     0.6065657267213038
# 6/25/2014     0.6065657267213038
# 7/8/2014      0.5880446358290503
# 4/27/2015     0.5834143631059869
#                     ...
# 11/2/2014   0.004630272723063388
# 3/8/2015    0.004630272723063388
# 1/31/2015   0.004630272723063388
# 2/15/2015   0.004630272723063388
# 5/24/2015   0.004630272723063388
# Name: date, Length: 372, dtype: float64
#
#
# price
# 350,000.0     0.7964069083669028
# 450,000.0     0.7964069083669028
# 550,000.0     0.7362133629670787
# 500,000.0      0.703801453905635
# 425,000.0     0.6945409084595082
#                     ...
# 870,515.0   0.004630272723063388
# 336,950.0   0.004630272723063388
# 386,100.0   0.004630272723063388
# 176,250.0   0.004630272723063388
# 884,744.0   0.004630272723063388
# Name: price, Length: 3622, dtype: float64
#
#
# bedrooms
# 3       45.48779923137472
# 4      31.865536880122242
# 2      12.779552715654951
# 5       7.413066629624485
# 6      1.2594341806732416
# 1      0.9075334537204242
# 7     0.17595036347640874
# 8     0.06019354539982405
# 9    0.027781636338380333
# 10   0.013890818169190166
# 11   0.004630272723063388
# 33   0.004630272723063388
# Name: bedrooms, dtype: float64
#
#
# bathrooms
# 2.5      24.896976431911842
# 1.0      17.831180256517108
# 1.75      14.11307125989721
# 2.25      9.478168264110757
# 2.0       8.936426355512339
# 1.5       6.690744084826596
# 2.75      5.486873176830116
# 3.0      3.4865953604667315
# 3.5      3.3847293605593367
# 3.25     2.7272306338843357
# 3.75     0.7176922720748252
# 4.0      0.6297170903366208
# 4.5     0.46302727230633883
# 4.25     0.3657915451220077
# 0.75     0.3287493633375006
# 4.75    0.10649627263045794
# 5.0     0.09723572718433116
# 5.25    0.06019354539982405
# 5.5     0.04630272723063388
# 1.25     0.0416724545075705
# 6.0    0.027781636338380333
# 5.75   0.018521090892253553
# 0.5    0.018521090892253553
# 8.0    0.009260545446126776
# 6.25   0.009260545446126776
# 6.75   0.009260545446126776
# 6.5    0.009260545446126776
# 7.5    0.004630272723063388
# 7.75   0.004630272723063388
# Name: bathrooms, dtype: float64
#
#
# sqft_living
# 1300     0.6389776357827476
# 1400     0.6250868176135574
# 1440     0.6158262721674307
# 1660     0.5973051812751772
# 1010     0.5973051812751772
#                ...
# 4970   0.004630272723063388
# 2905   0.004630272723063388
# 2793   0.004630272723063388
# 4810   0.004630272723063388
# 1975   0.004630272723063388
# Name: sqft_living, Length: 1034, dtype: float64
#
#
# sqft_lot
# 5000       1.6576376348566928
# 6000       1.3427790896883827
# 4000       1.1621984534889105
# 7200       1.0186599990739456
# 7500       0.5510024540445432
#                  ...
# 1448     0.004630272723063388
# 38884    0.004630272723063388
# 17313    0.004630272723063388
# 35752    0.004630272723063388
# 315374   0.004630272723063388
# Name: sqft_lot, Length: 9776, dtype: float64
#
#
# floors
# 1.0     49.418900773255544
# 2.0     38.130295874427006
# 1.5      8.843820901051073
# 3.0       2.82909663379173
# 2.5     0.7454739084132056
# 3.5   0.032411909061443714
# Name: floors, dtype: float64
#
#
# waterfront
# 0.0    99.24041413037823
# 1.0   0.7595858696217679
# Name: waterfront, dtype: float64
#
#
# view
# 0.0    90.19225410977988
# 2.0    4.444134856505991
# 3.0   2.3590600910188537
# 1.0   1.5324602953468933
# 4.0   1.4720906473483792
# Name: view, dtype: float64
#
#
# condition
# 3     64.91642357734871
# 4    26.286058248830855
# 5     7.876093901930823
# 2    0.7871463629207761
# 1   0.13427790896883826
# Name: condition, dtype: float64
#
#
# grade
# 7      41.552067416770846
# 8      28.082604065379453
# 9       12.10816317081076
# 6       9.436495809603187
# 10      5.250729267953883
# 11     1.8474788165022922
# 5        1.12052599898134
# 12    0.41209427235264157
# 4     0.12501736352271148
# 13    0.06019354539982405
# 3    0.004630272723063388
# Name: grade, dtype: float64
#
#
# sqft_above
# 1300     0.9816178172894383
# 1010     0.9723572718433114
# 1200      0.953836180951058
# 1220     0.8890123628281706
# 1140     0.8519701810436635
#                ...
# 2601   0.004630272723063388
# 440    0.004630272723063388
# 2473   0.004630272723063388
# 2441   0.004630272723063388
# 1975   0.004630272723063388
# Name: sqft_above, Length: 942, dtype: float64
#
#
# sqft_basement
# 0.0        59.387877946011024
# ?          2.1021438162707784
# 600.0      1.0047691809047552
# 500.0      0.9677269991202482
# 700.0      0.9630967263971848
#                  ...
# 2390.0   0.004630272723063388
# 266.0    0.004630272723063388
# 2810.0   0.004630272723063388
# 248.0    0.004630272723063388
# 172.0    0.004630272723063388
# Name: sqft_basement, Length: 304, dtype: float64
#
#
# yr_built
# 2014     2.588322452192434
# 2006     2.097513543547715
# 2005     2.083622725378525
# 2004    2.0049080890864475
# 2003    1.9447145436866229
#                ...
# 1933   0.13890818169190164
# 1901   0.13427790896883826
# 1902   0.12501736352271148
# 1935   0.11112654535352133
# 1934   0.09723572718433116
# Name: yr_built, Length: 116, dtype: float64
#
#
# yr_renovated
# 0.0          95.80963108983384
# 2,014.0      0.411151788228668
# 2,003.0    0.17459870459025625
# 2,013.0    0.17459870459025625
# 2,007.0    0.16896648831315123
#                   ...
# 1,946.0   0.005632216277105041
# 1,959.0   0.005632216277105041
# 1,971.0   0.005632216277105041
# 1,951.0   0.005632216277105041
# 1,954.0   0.005632216277105041
# Name: yr_renovated, Length: 70, dtype: float64
#
#
# zipcode
# 98103      2.78742417928416
# 98038    2.7272306338843357
# 98115    2.6994489975459555
# 98052     2.657776543038385
# 98117    2.5605408158540537
#                 ...
# 98102    0.4815483631985924
# 98010   0.46302727230633883
# 98024   0.37042181784507106
# 98148   0.26392554521461314
# 98039   0.23151363615316942
# Name: zipcode, Length: 70, dtype: float64
#
#
# lat
# 47.6624     0.0787146362920776
# 47.5491     0.0787146362920776
# 47.5322     0.0787146362920776
# 47.6846     0.0787146362920776
# 47.6711    0.07408436356901421
#                   ...
# 47.2785   0.004630272723063388
# 47.4162   0.004630272723063388
# 47.387    0.004630272723063388
# 47.2313   0.004630272723063388
# 47.2715   0.004630272723063388
# Name: lat, Length: 5033, dtype: float64
#
#
# long
# -122.29                 0.5324813631522897
# -122.3                  0.5139602722600362
# -122.36200000000001     0.4815483631985924
# -122.291               0.46302727230633883
# -122.37200000000001     0.4583969995832754
#                               ...
# -121.40299999999999   0.004630272723063388
# -121.804              0.004630272723063388
# -121.726              0.004630272723063388
# -121.895              0.004630272723063388
# -121.89299999999999   0.004630272723063388
# Name: long, Length: 751, dtype: float64
#
#
# sqft_living15
# 1540     0.9121637264434875
# 1440     0.9029031809973607
# 1560     0.8890123628281706
# 1500       0.83344909015141
# 1460     0.7825160901977126
#                ...
# 4890   0.004630272723063388
# 2873   0.004630272723063388
# 952    0.004630272723063388
# 3193   0.004630272723063388
# 2049   0.004630272723063388
# Name: sqft_living15, Length: 777, dtype: float64
#
#
# sqft_lot15
# 5000       1.9771264527480668
# 4000       1.6483770894105663
# 6000        1.333518544242256
# 7200       0.9723572718433114
# 4800       0.6713895448441913
#                  ...
# 11036    0.004630272723063388
# 8989     0.004630272723063388
# 871200   0.004630272723063388
# 809      0.004630272723063388
# 6147     0.004630272723063388
# Name: sqft_lot15, Length: 8682, dtype: float64

# %%
#create scatterplots for each column against target variable of price
for col in kchouse_df.columns: 
    plt.scatter(kchouse_df[col], kchouse_df.price, label=col)
    plt.legend()
    plt.xlabel(col)
    plt.ylabel('price')
    plt.title(col)
    plt.show()

# %% [markdown]
# ### Pandas Profiling Report on initial King County House Sale dataset
# [kchouseprofile_initial.html](kchouseprofile_initial.html)

# %% [markdown]
# ### Initial Observations
# <li>missing/null values in waterfront, view, and yr_renovated columns</li>
# <li>object datatypes for date and sqft_basement: categorical and numeric columns</li>
# <li>sqft_basement with ? values</li>
# <li>duplicate values in id column that accounts for < 1% of the data</li>
# <li>outlier in bedrooms - 33!</li>
# <li>possible correlations with price: bathrooms, sqft_living, grade, sqft_above, latitude, sqft_living15

# %% [markdown]
# ### Dealing with missing/null Values

# %% [markdown]
# waterfront column has 2376 missing values <br>
# view column has 63 missing values<br>
# yr_renovated column has 3842 missing values<br>

# %%
#call null values in dataframe
kchouse_df.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
#set null values to 0 
kchouse_df['waterfront'].fillna(0, inplace=True)
kchouse_df['view'].fillna(0, inplace=True)
kchouse_df['yr_renovated'].fillna(0, inplace=True)

# %%
kchouse_df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ### Dealing with object datatypes

# %% [markdown]
# object datatypes for date and sqft_basement: categorical and numeric columns

# %%
#convert date col object strings to datetime objects and call first 5 rows
kchouse_df['date'] = pd.to_datetime(kchouse_df.date, format='%m/%d/%Y')

# %%
#convert sqft_basement object strings to numerical datatype
kchouse_df['sqft_basement'] = pd.to_numeric(kchouse_df['sqft_basement'], errors='coerce')

# %%
#call datatypes
kchouse_df.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront              float64
# view                    float64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement           float64
# yr_built                  int64
# yr_renovated            float64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# dtype: object

# %% [markdown]
# ### Dealing with sqft_basement ? values

# %%
#set null values to 0 
kchouse_df['sqft_basement'].fillna(0, inplace=True)

# %%
#verifying replaced ? values
kchouse_df.sqft_basement.value_counts(bins=10)
# Out:
# (-4.821000000000001, 482.0]    15669
# (482.0, 964.0]                  3801
# (964.0, 1446.0]                 1697
# (1446.0, 1928.0]                 341
# (1928.0, 2410.0]                  71
# (2410.0, 2892.0]                  12
# (3374.0, 3856.0]                   2
# (2892.0, 3374.0]                   2
# (4338.0, 4820.0]                   1
# (3856.0, 4338.0]                   1
# Name: sqft_basement, dtype: int64

# %% [markdown]
# ### Dealing with outliers

# %% [markdown]
# outlier in bedrooms - 33!

# %%
#call row with to 33 bedrooms
kchouse_df.query('bedrooms == 33')
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15856  2402100895 2014-06-25 640,000.0        33       1.75         1620
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 15856      6000     1.0         0.0   0.0          5      7        1040
#
#        sqft_basement  yr_built  yr_renovated  zipcode     lat     long  \
# 15856          580.0      1947           0.0    98103 47.6878 -122.331
#
#        sqft_living15  sqft_lot15
# 15856           1330        4700

# %% [markdown]
# Given the property listing for id 2402100895, it seems the 33 bedrooms might be due to human error and should be 3 bedrooms.

# %%
#change 33 bedroom outlier to 3 bedrooms
kchouse_df.bedrooms[kchouse_df.bedrooms == 33] = 3

# %%
#call updated property id
kchouse_df.query('id == 2402100895')
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15856  2402100895 2014-06-25 640,000.0         3       1.75         1620
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 15856      6000     1.0         0.0   0.0          5      7        1040
#
#        sqft_basement  yr_built  yr_renovated  zipcode     lat     long  \
# 15856          580.0      1947           0.0    98103 47.6878 -122.331
#
#        sqft_living15  sqft_lot15
# 15856           1330        4700

# %% [markdown]
# ### Exporting out base dataset

# %%
#save cleaned dataframe as new csv file
kchouse_base = kchouse_df 
#kchouse_df.to_csv('kchouse_base.csv')

# %% [markdown]
# ## Initial visualizations

# %%
#create plot of map coordinates from dataframe
plt.figure(figsize=(8,10))
sns.scatterplot(x='long', y='lat', hue='price', data=kchouse_base, palette='Paired')
plt.title('Lat & Long Home Sales with Price Index by Color')
plt.legend(fancybox=True);

# %%
#create histograms from dataframe
kchouse_base.hist(figsize=(20,18))
# Out:
# array([[<AxesSubplot:title={'center':'bathrooms'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'condition'}>,
#         <AxesSubplot:title={'center':'floors'}>],
#        [<AxesSubplot:title={'center':'grade'}>,
#         <AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'lat'}>,
#         <AxesSubplot:title={'center':'long'}>],
#        [<AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'sqft_above'}>,
#         <AxesSubplot:title={'center':'sqft_basement'}>,
#         <AxesSubplot:title={'center':'sqft_living'}>],
#        [<AxesSubplot:title={'center':'sqft_living15'}>,
#         <AxesSubplot:title={'center':'sqft_lot'}>,
#         <AxesSubplot:title={'center':'sqft_lot15'}>,
#         <AxesSubplot:title={'center':'view'}>],
#        [<AxesSubplot:title={'center':'waterfront'}>,
#         <AxesSubplot:title={'center':'yr_built'}>,
#         <AxesSubplot:title={'center':'yr_renovated'}>,
#         <AxesSubplot:title={'center':'zipcode'}>]], dtype=object)

# %% [markdown]
# #### Sweet Viz visualization

# %%
#create sweet viz visualizations and export to html
#sweetviz_base = sv.analyze(kchouse_base, target_feat = 'price')
#sweetviz_base.show_html('sweetviz_base.html')

# %% [markdown]
# ##### Link to baseline Sweet Viz visualizations: [sweetviz_base.html](sweetviz_base.html)

# %% [markdown]
# #### Pandas Profiling base report

# %% [markdown]
# ##### Link to baseline profile: [kchouseprofile_base.html](kchouseprofile_base.html)

# %%
#create correlation heatmap to visualize collinearity
plt.figure(figsize=(16, 12))
pcorr = kchouse_base.corr()
cmap = 'RdBu_r'
sns.heatmap(pcorr, 
            xticklabels=pcorr.columns, 
            yticklabels=pcorr.columns,
            cmap=cmap,
            annot=True,
            linewidth=0.5,
            center=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Baseline Model

# %%
#call OLS Regression summary for baseline model
data = kchouse_base
target = 'price'
x_cols = kchouse_base.drop([target, 'date','id'], axis=1).columns
predictors = '+'.join(x_cols)
f = target + '~' + predictors

model = smf.ols(formula=f, data=data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.700
# Method:                 Least Squares   F-statistic:                     2805.
# Date:                Wed, 27 Jan 2021   Prob (F-statistic):               0.00
# Time:                        19:30:59   Log-Likelihood:            -2.9437e+05
# No. Observations:               21597   AIC:                         5.888e+05
# Df Residuals:                   21578   BIC:                         5.889e+05
# Df Model:                          18
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      7.012e+06   2.93e+06      2.394      0.017    1.27e+06    1.28e+07
# bedrooms      -3.927e+04   1978.729    -19.848      0.000   -4.32e+04   -3.54e+04
# bathrooms      4.271e+04   3264.908     13.082      0.000    3.63e+04    4.91e+04
# sqft_living     105.1993     18.065      5.823      0.000      69.790     140.608
# sqft_lot          0.1257      0.048      2.625      0.009       0.032       0.220
# floors         6903.1586   3597.639      1.919      0.055    -148.480     1.4e+04
# waterfront     6.167e+05   1.81e+04     34.031      0.000    5.81e+05    6.52e+05
# view           5.302e+04   2120.714     25.000      0.000    4.89e+04    5.72e+04
# condition      2.679e+04   2344.216     11.426      0.000    2.22e+04    3.14e+04
# grade          9.639e+04   2160.483     44.613      0.000    9.22e+04    1.01e+05
# sqft_above       77.6563     18.052      4.302      0.000      42.273     113.039
# sqft_basement    47.3419     17.891      2.646      0.008      12.273      82.411
# yr_built      -2647.3323     71.888    -36.826      0.000   -2788.239   -2506.426
# yr_renovated     23.3683      3.974      5.880      0.000      15.579      31.158
# zipcode        -587.3000     32.966    -17.815      0.000    -651.915    -522.685
# lat            5.995e+05   1.07e+04     55.876      0.000    5.79e+05    6.21e+05
# long          -2.177e+05   1.31e+04    -16.563      0.000   -2.43e+05   -1.92e+05
# sqft_living15    21.5425      3.448      6.249      0.000      14.785      28.300
# sqft_lot15       -0.3934      0.073     -5.367      0.000      -0.537      -0.250
# ==============================================================================
# Omnibus:                    18266.149   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1810077.584
# Skew:                           3.541   Prob(JB):                         0.00
# Kurtosis:                      47.287   Cond. No.                     2.15e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Baseline Observations

# %% [markdown]
# <li>R-squared value = .701</li>
# <li>high p-value for floors column</li>

# %% [markdown]
# ## Features and Transformations

# %% [markdown]
# From initial observations, possible correlations with price:
# <li>bathrooms</li>
# <li>sqft_living</li>
# <li>grade</li>
# <li>sqft_above</li>
# <li>latitude</li>
# <li>sqft_living15</li>
# <br>
# sqft_above is likely dependent on sqft_living.

# %% [markdown]
# ### Adding Cities by Zipcode

# %%
#importing zipcode by city csv in dataframe
kczipcity_df = pd.read_csv('kc_city_zip.csv')
kczipcity_df.head()
# Out:
#    zipcode         city
# 0    98001       Auburn
# 1    98002       Auburn
# 2    98003  Federal Way
# 3    98004     Bellevue
# 4    98005     Bellevue

# %%
#create new dataframe by joining the baseline with the cities on zipcode
kchouse_cities = pd.merge(left=kchouse_base, right=kczipcity_df, how='left', left_on='zipcode', right_on='zipcode')
kchouse_cities.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13 221,900.0         3        1.0         1180
# 1  6414100192 2014-12-09 538,000.0         3       2.25         2570
# 2  5631500400 2015-02-25 180,000.0         2        1.0          770
# 3  2487200875 2014-12-09 604,000.0         4        3.0         1960
# 4  1954400510 2015-02-18 510,000.0         3        2.0         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0         0.0   0.0          3      7        1180
# 1      7242     2.0         0.0   0.0          3      7        2170
# 2     10000     1.0         0.0   0.0          3      6         770
# 3      5000     1.0         0.0   0.0          5      7        1050
# 4      8080     1.0         0.0   0.0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode                lat  \
# 0            0.0      1955           0.0    98178            47.5112
# 1          400.0      1951       1,991.0    98125 47.721000000000004
# 2            0.0      1933           0.0    98028            47.7379
# 3          910.0      1965           0.0    98136            47.5208
# 4            0.0      1987           0.0    98074            47.6168
#
#                  long  sqft_living15  sqft_lot15       city
# 0            -122.257           1340        5650    Seattle
# 1            -122.319           1690        7639    Seattle
# 2 -122.23299999999999           2720        8062    Kenmore
# 3 -122.39299999999999           1360        5000    Seattle
# 4            -122.045           1800        7503  Sammamish

# %%
#return summary stats for cities 
kchouse_cities.groupby('city').describe()
# Out:
#                    id                                              \
#                 count                  mean                   std
# city
# Auburn          911.0  4,391,561,101.743139 2,621,595,218.8806214
# Bellevue      1,407.0  4,588,338,529.041933 2,885,039,700.0034976
# Black Diamond   100.0      3,879,195,406.67 2,428,714,466.2755647
# Bothell         195.0 4,284,960,781.1076922 3,013,550,236.6414323
# Carnation       124.0 4,240,655,613.4919353  2,897,836,737.169101
# Duvall          190.0  3,137,917,864.836842  2,458,831,056.923274
# Enumclaw        233.0  4,014,550,115.064378 2,665,955,754.0153384
# Fall City        80.0      2,802,980,843.95 2,055,222,045.0486171
# Federal Way     779.0  5,200,648,122.595635 3,129,100,179.9674997
# Issaquah        733.0  4,882,344,448.540246 2,656,710,734.3133082
# Kenmore         283.0  4,415,450,815.212014  2,636,876,059.906162
# Kent          1,201.0  4,587,595,856.955037  2,842,248,759.152632
# Kirkland        977.0  4,050,049,508.701126 2,607,251,850.2499137
# Maple Valley    589.0 4,129,010,039.2037354  2,834,228,482.421144
# Medina           50.0      3,755,708,209.12 1,658,801,573.5301495
# Mercer Island   282.0 4,199,322,940.6631207   2,330,590,758.52713
# North Bend      220.0  5,017,308,158.918181 3,525,319,989.9147325
# Redmond         977.0    5,301,261,366.0174  3,113,687,795.049796
# Renton        1,597.0  4,324,540,614.540388  2,848,397,603.867124
# Sammamish       800.0    4,881,567,672.7725 3,156,961,664.0224814
# Seattle       8,973.0  4,603,227,499.785133 2,843,007,448.2474337
# Medina        3,811,127,128.75 9,208,900,037.0    50.0          2,161,300.0
# Mercer Island  5,453,700,050.0 9,365,700,385.0   282.0 1,194,873.6382978724
# North Bend    8,566,370,215.75 9,510,320,150.0   220.0  440,232.31363636366
# Redmond        8,087,800,400.0 9,578,090,240.0   977.0   658,431.7758444217
# Renton         7,227,800,025.0 9,564,800,145.0 1,597.0   403,468.4608641202
# Sammamish      7,715,800,400.0 9,544,700,730.0   800.0         732,821.0075
# Seattle        7,234,600,098.0 9,900,000,190.0 8,973.0   535,085.5999108437
# Snoqualmie     7,853,301,757.5 9,474,700,020.0   308.0   529,629.7824675324
# Vashon         3,523,029,041.0 8,888,000,055.0   117.0   489,382.0170940171
# Woodinville    7,214,710,255.0 9,562,200,090.0   471.0   617,497.8704883227
#
#                                               ... sqft_living15          \
#                                std       min  ...           25%     50%
# city                                          ...
# Auburn         108,421.78012876672  90,000.0  ...       1,465.0 1,780.0
# Bellevue        559,781.8122975279 247,500.0  ...       1,940.0 2,410.0
# Black Diamond  195,414.98276229948 135,000.0  ...       1,530.0 1,860.0
# Bothell        121,970.78686039543 245,500.0  ...       1,890.0 2,160.0
# Carnation      258,603.42393995257  80,000.0  ...       1,425.0 1,855.0
# Duvall         130,638.25698614071 119,500.0  ...       1,707.5 2,075.0
# Enumclaw        122,328.9394245304 122,000.0  ...       1,450.0 1,690.0
# Fall City      376,718.73313326016 200,000.0  ...       1,432.5 1,980.0
# Federal Way    108,398.64613767962  86,500.0  ...       1,540.0 1,870.0
# Issaquah       260,450.91531555232 130,000.0  ...       1,800.0 2,210.0
# Kenmore        149,529.73679449302 160,000.0  ...       1,760.0 2,040.0
# Kent            91,647.45282324315  85,000.0  ...       1,540.0 1,860.0
# Kirkland       409,632.75207085826  90,000.0  ...       1,590.0 1,930.0
# Maple Valley   132,721.03360330555 110,000.0  ...       1,660.0 2,020.0
# Medina        1,166,904.3994908154 787,500.0  ...       2,810.0 3,105.0
# Mercer Island   607,767.6418930267 500,000.0  ...       2,390.0 2,875.0
# North Bend      207,554.1179117507 175,000.0  ...       1,390.0 1,680.0
# Redmond        231,135.94253262423 170,000.0  ...       1,800.0 2,290.0
# Renton         200,724.56987086838  95,000.0  ...       1,560.0 1,940.0
# Sammamish      280,951.29642198473 280,000.0  ...       2,280.0 2,770.0
# Seattle         340,518.6305404255  78,000.0  ...       1,340.0 1,580.0
# Snoqualmie     185,253.81700181187 170,000.0  ...       1,970.0 2,440.0
# Vashon          201,500.7500399741 160,000.0  ...       1,530.0 1,760.0
# Woodinville    244,297.68081071903 200,000.0  ...       1,970.0 2,510.0
#
#                               sqft_lot15                      \
#                   75%     max      count                mean
# city
# Auburn        2,240.0 4,670.0      911.0  17,742.69703622393
# Bellevue      2,925.0 6,110.0    1,407.0 12,251.945984363894
# Black Diamond 2,202.5 4,100.0      100.0           47,830.27
# Bothell       2,570.0 4,590.0      195.0   9,512.08717948718
# Carnation     2,380.0 5,030.0      124.0  77,979.62096774194
# Duvall        2,445.0 3,620.0      190.0  37,016.51052631579
# Bellevue      167,378.0
# Black Diamond 339,332.0
# Bothell        56,628.0
# Carnation     871,200.0
# Duvall        434,728.0
# Enumclaw      560,617.0
# Fall City     310,582.0
# Federal Way    72,229.0
# Issaquah      223,027.0
# Kenmore        44,634.0
# Kent          298,182.0
# Kirkland       51,376.0
# Maple Valley  229,996.0
# Medina         42,730.0
# Mercer Island  36,563.0
# North Bend    283,140.0
# Redmond       223,463.0
# Renton        217,800.0
# Sammamish     212,137.0
# Seattle       128,066.0
# Snoqualmie    411,962.0
# Vashon        380,279.0
# Woodinville   266,587.0
#
# [24 rows x 160 columns]

# %%
#group dataframe by city
kchouse_cities.groupby('city').sum()
# Out:
#                            id           price  bedrooms  bathrooms  \
# city
# Auburn          4000712163688   265,691,164.0      3116    1,878.5
# Bellevue        6455792310362 1,264,141,779.0      5377   3,378.75
# Black Diamond    387919540667    42,366,599.0       329     202.75
# Bothell          835567352316    95,623,536.0       692     444.25
# Carnation        525841296073    56,496,522.0       372      254.0
# Duvall           596204394319    80,714,862.0       639     435.25
# Enumclaw         935390176810    73,800,977.0       736      447.0
# Fall City        224238467516    46,889,670.0       267     175.25
# Federal Way     4051304887502   225,435,821.0      2649    1,602.0
# Issaquah        3578758480780   450,884,553.0      2557   1,851.25
# Kenmore         1249572580705   130,884,350.0       985      606.5
# Kent            5509702624203   359,663,527.0      4137    2,518.5
# Kirkland        3956898370001   631,672,342.0      3428    2,165.5
# Maple Valley    2431986913091   216,216,884.0      2027   1,399.25
# Medina           187785410456   108,065,000.0       203      160.0
# Mercer Island   1184209069267   336,954,366.0      1136      766.0
# North Bend      1103807794962    96,851,109.0       713      466.5
# Redmond         5179332354599   643,287,845.0      3376   2,348.75
# Renton          6906291361421   644,339,132.0      5602   3,401.75
# Sammamish       3905254138218   586,256,806.0      2983    2,084.5
# Seattle        41304760355572 4,801,323,088.0     28422  16,998.75
# Snoqualmie      2276366455465   163,125,973.0      1092      786.5
# Vashon           382293914407    57,257,696.0       325      223.5
# Woodinville     1754512780590   290,841,497.0      1658    1,100.5
#
#                sqft_living  sqft_lot   floors  waterfront    view  condition  \
# city
# Auburn             1781864  18304715  1,345.0         0.0    84.0       3114
# Bellevue           3718309  18553797  1,929.5        14.0   566.0       5101
# Black Diamond       213759   5546530    148.0         0.0    10.0        353
# Bothell             439354   2206257    293.0         0.0    12.0        628
# Carnation           262628  12015955    186.5         0.0    23.0        391
# Duvall              412596   7569293    327.0         0.0     4.0        584
# Enumclaw            428094  17296502    308.5         0.0   147.0        870
# Fall City           189045   8218835    114.0         0.0    19.0        261
# Federal Way        1532962   8193501  1,027.5         3.0   119.0       2634
# Issaquah           1769249  16323257  1,314.5         2.0    90.0       2403
# Kenmore             600731   3377711    402.0         1.0    46.0        934
# Kent               2330450  17996871  1,750.5         0.0    36.0       4177
# Kirkland           2107107   9860262  1,364.0         8.0   239.0       3348
# Maple Valley       1265342  14971867  1,025.0         0.0    16.0       1881
# Medina              190045    870178     78.0         1.0    22.0        174
# Mercer Island       876127   3864659    424.5        11.0   216.0       1068
# Snoqualmie      30204020 14,639.783699999987   -37,533.54399999999
# Vashon          11474190  5,547.838199999997   -14,328.23999999999
# Woodinville     46192902 22,489.720000000027   -57,510.14699999997
#
#                sqft_living15  sqft_lot15
# city
# Auburn               1702631    16163597
# Bellevue             3538096    17238488
# Black Diamond         200876     4783027
# Bothell               438375     1854857
# Carnation             239198     9669473
# Duvall                399707     7033137
# Enumclaw              419760    11996802
# Fall City             170766     6358749
# Federal Way          1505237     7586897
# Issaquah             1689559    13977021
# Kenmore               591838     2863877
# Kent                 2290775    13718379
# Kirkland             1997517     8914749
# Maple Valley         1248059    11826628
# Medina                156610      864555
# Mercer Island         817446     3609962
# North Bend            421955     7089966
# Redmond              2335524    17503059
# Renton               3251252    17402218
# Sammamish            2209938    11217047
# Seattle             15099805    55474551
# Snoqualmie            778105     3473067
# Vashon                207760     9367981
# Woodinville          1194250    15552562

# %%
#group dataframe by city by median price
kchouse_cities.groupby('city')['price'].median()
# Out:
# city
# Auburn            270,000.0
# Bellevue          749,000.0
# Black Diamond     359,999.5
# Bothell           470,000.0
# Carnation         415,000.0
# Duvall            401,250.0
# Enumclaw          280,000.0
# Fall City         462,500.0
# Federal Way       268,000.0
# Issaquah          572,000.0
# Kenmore           445,000.0
# Kent              283,000.0
# Kirkland          510,000.0
# Maple Valley      342,000.0
# Medina          1,895,000.0
# Mercer Island     993,750.0
# North Bend        404,750.0
# Redmond           625,000.0
# Renton            358,000.0
# Sammamish         688,500.0
# Seattle           453,000.0
# Snoqualmie        502,500.0
# Vashon            465,000.0
# Woodinville       570,000.0
# Name: price, dtype: float64

# %%
#summary stats of grouped dataframe by city by price
kchouse_cities.groupby('city')['price'].describe()
# Out:
#                 count                 mean                  std       min  \
# city
# Auburn          911.0   291,647.8199780461  108,421.78012876672  90,000.0
# Bellevue      1,407.0   898,466.0831556503   559,781.8122975279 247,500.0
# Black Diamond   100.0           423,665.99  195,414.98276229948 135,000.0
# Bothell         195.0   490,377.1076923077  121,970.78686039543 245,500.0
# Carnation       124.0   455,617.1129032258  258,603.42393995257  80,000.0
# Duvall          190.0  424,815.06315789477  130,638.25698614071 119,500.0
# Enumclaw        233.0   316,742.3905579399   122,328.9394245304 122,000.0
# Fall City        80.0          586,120.875  376,718.73313326016 200,000.0
# Federal Way     779.0  289,391.29781771504  108,398.64613767962  86,500.0
# Issaquah        733.0    615,122.173260573  260,450.91531555232 130,000.0
# Kenmore         283.0   462,488.8692579505  149,529.73679449302 160,000.0
# Kent          1,201.0   299,470.0474604496   91,647.45282324315  85,000.0
# Kirkland        977.0   646,542.8270214944  409,632.75207085826  90,000.0
# Maple Valley    589.0  367,091.48387096776  132,721.03360330555 110,000.0
# Medina           50.0          2,161,300.0 1,166,904.3994908154 787,500.0
# Mercer Island   282.0 1,194,873.6382978724   607,767.6418930267 500,000.0
# North Bend      220.0  440,232.31363636366   207,554.1179117507 175,000.0
# Redmond         977.0   658,431.7758444217  231,135.94253262423 170,000.0
# Renton        1,597.0   403,468.4608641202  200,724.56987086838  95,000.0
# Sammamish       800.0         732,821.0075  280,951.29642198473 280,000.0
# Seattle       8,973.0   535,085.5999108437   340,518.6305404255  78,000.0
# Snoqualmie      308.0   529,629.7824675324  185,253.81700181187 170,000.0
# Vashon          117.0   489,382.0170940171   201,500.7500399741 160,000.0
# Woodinville     471.0   617,497.8704883227  244,297.68081071903 200,000.0
#
#                       25%         50%         75%         max
# city
# Auburn          224,250.0   270,000.0   332,550.0   930,000.0
# Bellevue        550,000.0   749,000.0   999,974.5 7,060,000.0
# Black Diamond   256,750.0   359,999.5   592,500.0   935,000.0
# Bothell         412,400.0   470,000.0   550,000.0 1,080,000.0
# Carnation       308,500.0   415,000.0   536,000.0 1,680,000.0
# Duvall         330,168.75   401,250.0   499,987.5 1,020,000.0
# Enumclaw        235,000.0   280,000.0   350,000.0   858,000.0
# Fall City       340,000.0   462,500.0   702,500.0 1,860,000.0
# Federal Way     225,450.0   268,000.0   320,000.0 1,280,000.0
# Issaquah        467,000.0   572,000.0   695,000.0 2,700,000.0
# Kenmore         379,975.0   445,000.0   525,875.0 1,600,000.0
# Kent            245,000.0   283,000.0   339,950.0   859,000.0
# Kirkland        425,000.0   510,000.0   739,000.0 5,110,000.0
# Maple Valley    286,000.0   342,000.0   410,000.0 1,350,000.0
# Medina        1,402,500.0 1,895,000.0 2,560,000.0 6,890,000.0
# Mercer Island   822,000.0   993,750.0 1,387,500.0 5,300,000.0
# North Bend      306,500.0   404,750.0   495,250.0 1,950,000.0
# Redmond         500,000.0   625,000.0   766,000.0 2,280,000.0
# Renton          290,300.0   358,000.0   460,000.0 3,000,000.0
# Sammamish       568,000.0   688,500.0  829,996.25 3,200,000.0
# Seattle         337,000.0   453,000.0   630,000.0 7,700,000.0
# Snoqualmie      425,000.0   502,500.0   619,250.0 2,000,000.0
# Vashon          350,000.0   465,000.0   575,000.0 1,380,000.0
# Woodinville     442,500.0   570,000.0   751,412.5 1,920,000.0

# %% [markdown]
# R-squared value up to .755

# %% [markdown]
# #### OLS - Cities

# %%
#call OLS Regression summary
data = kchouse_cities
target = 'price'
x_cols = kchouse_cities.drop([target, 'date','id'], axis=1).columns
predictors = '+'.join(x_cols)
f = target + '~' + predictors

model = smf.ols(formula=f, data=data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.755
# Model:                            OLS   Adj. R-squared:                  0.755
# Method:                 Least Squares   F-statistic:                     1621.
# Date:                Wed, 27 Jan 2021   Prob (F-statistic):               0.00
# Time:                        19:31:27   Log-Likelihood:            -2.9220e+05
# No. Observations:               21597   AIC:                         5.845e+05
# Df Residuals:                   21555   BIC:                         5.848e+05
# Df Model:                          41
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept              7.423e+07   7.95e+06      9.341      0.000    5.87e+07    8.98e+07
# city[T.Bellevue]       1.997e+05   9976.349     20.017      0.000     1.8e+05    2.19e+05
# city[T.Black Diamond]  1.029e+05   2.04e+04      5.033      0.000    6.28e+04    1.43e+05
# city[T.Bothell]       -1.254e+05   1.69e+04     -7.437      0.000   -1.58e+05   -9.23e+04
# city[T.Carnation]      3.615e+04   2.23e+04      1.622      0.105   -7524.268    7.98e+04
# city[T.Duvall]        -4.054e+04   1.88e+04     -2.151      0.031   -7.75e+04   -3597.298
Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2335449.717
# Skew:                           3.703   Prob(JB):                         0.00
# Kurtosis:                      53.403   Cond. No.                     6.46e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.46e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Change of R-squared value to .755 from .701!

# %% [markdown]
# ### Looking at bathrooms

# %%
kchouse_cities.groupby('bathrooms').sum()

# %%
#filter dataframe by bathrooms less than .75
kchouse_cities.query('bathrooms < .75')

# %% [markdown]
# Less than .75 bathrooms mean these house do not have a bathtub or shower! Not good.

# %%
#filter dataframe by bathrooms less than .75 by id col
kchouse_cities.query('bathrooms < .75')['id']

# %%
#drop rows with only .5 bathrooms using row id and set to new dataframe
kchousecities_baths = kchouse_cities.drop([2259, 10413, 11662, 12029], axis=0)

# %%
#verify new dataframe
kchousecities_baths.query('bathrooms < .75')

# %% [markdown]
# ### Condition and Grade

# %% [markdown]
# Looking at the definitions from the King County Assessor's office for building condition and grade, adding a feature for properties that are up to building codes and habitable: properties at condition 3 or above + grade 6 or above. <br>
# Notebook: [King County House Sale Columns](kchouse_columns.ipynb)

# %%
#filtering dataframe by condition and grade
kchousecities_baths.query('condition >= 3' and 'grade >= 6').head()

# %%
#new dataframe
kchouse_livable = kchousecities_baths

# %%
#create new col by filtering out by condition and grade
kchouse_livable['livable'] = '0'
kchouse_livable.loc[(kchouse_livable['condition'] >= 3) & (kchouse_livable['grade'] >= 6), 'livable'] = '1'
kchouse_livable.head()

# %%
kchouse_livable.query('condition < 3' and 'grade < 6').head()

# %% [markdown]
# ### Dates to Quarters

# %% [markdown]
# Grouping sales by Quarter.

# %%
kchouse_livable.groupby(pd.Grouper(key='date', freq='Q')).describe()

# %%
kchouse_qrtrs = kchouse_livable

# %%
#create new quarter columns and one-hot encode as numerical data

kchouse_qrtrs['q2_2014'] = '0'
kchouse_qrtrs['q3_2014'] = '0'
kchouse_qrtrs['q4_2014'] = '0'
kchouse_qrtrs['q1_2015'] = '0'
kchouse_qrtrs['q2_2015'] = '0'

kchouse_qrtrs.loc[(kchouse_qrtrs['date'] <= '2014-06-30') & (kchouse_qrtrs['date'] > '2014-03-31'), 'q2_2014'] = '1'
kchouse_qrtrs.loc[(kchouse_qrtrs['date'] <= '2014-09-30') & (kchouse_qrtrs['date'] > '2014-06-30'), 'q3_2014'] = '1'
kchouse_qrtrs.loc[(kchouse_qrtrs['date'] <= '2014-12-31') & (kchouse_qrtrs['date'] > '2014-09-30'), 'q4_2014'] = '1'
kchouse_qrtrs.loc[(kchouse_qrtrs['date'] <= '2015-03-31') & (kchouse_qrtrs['date'] > '2014-12-31'), 'q1_2015'] = '1'
kchouse_qrtrs.loc[(kchouse_qrtrs['date'] <= '2015-06-30') & (kchouse_qrtrs['date'] > '2015-03-31'), 'q2_2015'] = '1'

kchouse_qrtrs.head()

# %% [markdown]
# ### Cleaning up datatypes

# %%
kchouse_qrtrs.dtypes

# %%
#convert object datatype columns to numerical datatypes
kchouse_qrtrs['livable'] = pd.to_numeric(kchouse_qrtrs['livable'], errors='coerce')
kchouse_qrtrs['q2_2014'] = pd.to_numeric(kchouse_qrtrs['q2_2014'], errors='coerce')
kchouse_qrtrs['q3_2014'] = pd.to_numeric(kchouse_qrtrs['q3_2014'], errors='coerce')
kchouse_qrtrs['q4_2014'] = pd.to_numeric(kchouse_qrtrs['q4_2014'], errors='coerce')
kchouse_qrtrs['q1_2015'] = pd.to_numeric(kchouse_qrtrs['q1_2015'], errors='coerce')
kchouse_qrtrs['q2_2015'] = pd.to_numeric(kchouse_qrtrs['q2_2015'], errors='coerce')

kchouse_qrtrs.dtypes

# %% [markdown]
# #### OLS - Bathrooms / Livable / Quarters

# %%
#call OLS Regression summary
data = kchouse_qrtrs
target = 'price'
x_cols = kchouse_qrtrs.drop([target, 'date','id'], axis=1).columns
predictors = '+'.join(x_cols)
f = target + '~' + predictors

model = smf.ols(formula=f, data=data).fit()
model.summary()

# %% [markdown]
# R-Squared value up to .775

# %% [markdown]
# ### Categorical vs Continous data

# %% [markdown]
# Looking at categorical and continuous variables

# %%
#call custom summary stats function over updated dataframe 
eda_table(kchouse_qrtrs)

# %%
#create lists of categorical vs continuous columns using a for loop
cats = ['bathrooms', 'bedrooms', 'city', 'condition', 'floors', 'grade', 'livable', 'q2_2014', 'q3_2014', 'q4_2014', 'q1_2015', 'q2_2015', 'view', 'waterfront', 'yr_built', 'yr_renovated', 'zipcode']
conts = ['price', 'sqft_above', 'sqft_basement', 'sqft_living', 'sqft_living15', 'sqft_lot15']
    
print(cats)
print(conts)

# %%
kchouse_conts = kchouse_qrtrs.loc[:,conts]
kchouse_cats = kchouse_qrtrs.loc[:,cats]

# %%
kchouse_conts.hist(figsize=(12,10))
kchouse_conts.describe()

# %% [markdown]
# ### Log Transformation of continuous variables

# %% [markdown]
# Normalizing distributions of continuous variable data.

# %%
log_kchouse_qrtrs = kchouse_qrtrs

# %%
#create new log transformed columns for variables and plot histograms
log_sqft_living = np.log(kchouse_qrtrs['sqft_living'])
log_sqft_lot = np.log(kchouse_qrtrs['sqft_lot'])
log_sqft_above = np.log(kchouse_qrtrs['sqft_above'])
log_sqft_living15 = np.log(kchouse_qrtrs['sqft_living15'])
log_sqft_lot15 = np.log(kchouse_qrtrs['sqft_lot15'])

logs = ['log_sqft_living', 'log_sqft_lot', 'log_sqft_above', 'log_sqft_living15', 'log_sqft_lot15']

log_kchouse_qrtrs['log_sqft_living'] = log_sqft_living
log_kchouse_qrtrs['log_sqft_lot'] = log_sqft_lot
log_kchouse_qrtrs['log_sqft_above'] = log_sqft_above
log_kchouse_qrtrs['log_sqft_living15'] = log_sqft_living15
log_kchouse_qrtrs['log_sqft_lot15'] = log_sqft_lot15

log_kchouse_qrtrs[logs].hist(figsize=(10,10));

# %%
log_kchouse_qrtrs.head()

# %% [markdown]
# #### OLS - Logs

# %%
#call OLS Regression summary
data = log_kchouse_qrtrs
target = 'price'
x_cols = log_kchouse_qrtrs.drop([target, 'date','id'], axis=1).columns
predictors = '+'.join(x_cols)
f = target + '~' + predictors

model = smf.ols(formula=f, data=data).fit()
model.summary()

# %% [markdown]
# R-Squared Value still .775 with log transforms.

# %% [markdown]
# ### Exporting out dataset

# %%
#log_kchouse_qrtrs.to_csv('kchouse_model.csv')
